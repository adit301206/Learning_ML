# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# ### What is it?

# %% [markdown]
# #### In this when we have more columns so the data is considered as multi dimensional like more than 3 so we need to reduce its dimension as we can only visualise the data in 2D or maybe 3D.
